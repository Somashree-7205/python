# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings ("ignore")

# %%
df=pd.read_excel('EDA Cars-1.xlsx')

# %%
df.head()
# Out:
#    INDEX        INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0      1  125301.24250             No   F    Bachelors  Blue Collar
# 1      2   50815.44531             No   M  High School          NaN
# 2      3   62977.82416            NaN   F    Bachelors     Clerical
# 3      4   77099.96624             No   F          NaN       Lawyer
# 4      5  130794.57420             No   M  High School          NaN
#
#    TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE   CITY  \
# 0    45.703013  Commercial        17430.0   Sports Car      7.0  Texas
# 1    20.591628     Private        18930.0      Minivan      1.0  Texas
# 2    33.639949     Private            NaN          SUV      1.0  Texas
# 3    15.415676         NaN        18300.0   Sports Car     11.0  Texas
# 4          NaN  Commercial        28340.0  Panel Truck     10.0  Texas
#
#    POSTAL CODE
# 0      42420.0
# 1      42420.0
# 2      42420.0
# 3      42420.0
# 4      42420.0

# %%
df.shape
# Out:
# (303, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INDEX           303 non-null    int64
#  1   INCOME          260 non-null    float64
#  2   MARITAL STATUS  275 non-null    object
#  3   SEX             297 non-null    object
#  4   EDUCATION       259 non-null    object
#  5   JOB             257 non-null    object
#  6   TRAVEL TIME     262 non-null    float64
#  7   USE             250 non-null    object
#  8   MILES CLOCKED   278 non-null    float64
#  9   CAR TYPE        293 non-null    object
#  10  CAR AGE         283 non-null    float64
#  11  CITY            297 non-null    object
#  12  POSTAL CODE     300 non-null    float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 30.9+ KB

# %%
df.describe(include="all")
# Out:
#              INDEX         INCOME MARITAL STATUS  SEX    EDUCATION  \
# count   303.000000     260.000000            275  297          259
# unique         NaN            NaN              2    2            4
# top            NaN            NaN             No    F  High School
# freq           NaN            NaN            151  165          161
# mean    139.640264   50025.162170            NaN  NaN          NaN
# std      85.178422   41186.807914            NaN  NaN          NaN
# min       1.000000       0.000000            NaN  NaN          NaN
# 25%      62.500000   20452.885023            NaN  NaN          NaN
# 50%     138.000000   44571.590870            NaN  NaN          NaN
# 75%     213.500000   66485.761387            NaN  NaN          NaN
# max     289.000000  204667.589700            NaN  NaN          NaN
#
#                 JOB  TRAVEL TIME      USE  MILES CLOCKED CAR TYPE     CAR AGE  \
# count           257   262.000000      250     278.000000      293  283.000000
# ...

# %%
## missing value

df.isnull().sum()
# Out:
# INDEX              0
# INCOME            43
# MARITAL STATUS    28
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME       41
# USE               53
# MILES CLOCKED     25
# CAR TYPE          10
# CAR AGE           20
# CITY               6
# POSTAL CODE        3
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 325

# %%
df.dropna().shape
# Out:
# (108, 13)

# %%
dups=df.duplicated()
df[dups]
# Out:
#     INDEX       INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 69     29  64013.81632            Yes   M  High School  Blue Collar
# 70     29  64013.81632            Yes   M  High School  Blue Collar
# 71     29  64013.81632            Yes   M  High School  Blue Collar
# 72     29  64013.81632            Yes   M  High School  Blue Collar
# 73     29  64013.81632            Yes   M  High School  Blue Collar
# 74     29  64013.81632            Yes   M  High School  Blue Collar
# 75     29  64013.81632            Yes   M  High School  Blue Collar
# 76     29  64013.81632            Yes   M  High School  Blue Collar
# 77     29  64013.81632            Yes   M  High School  Blue Collar
# 78     29  64013.81632            Yes   M  High School  Blue Collar
# 79     29  64013.81632            Yes   M  High School  Blue Collar
# 80     29  64013.81632            Yes   M  High School  Blue Collar
# 81     29  64013.81632            Yes   M  High School  Blue Collar
# ...

# %%
df[dups].shape
# Out:
# (14, 13)

# %%
##DROPING DUPLICATES

df.drop_duplicates(inplace=True)

# %%
df[dups]
# Out:
# Empty DataFrame
# Columns: [INDEX, INCOME, MARITAL STATUS, SEX, EDUCATION, JOB, TRAVEL TIME, USE, MILES CLOCKED, CAR TYPE, CAR AGE, CITY, POSTAL CODE]
# Index: []

# %%
##MISSING VALUE TREATMENT

df[df.isnull().sum()[df.isnull().sum()>0].index].dtypes
# Out:
# INCOME            float64
# MARITAL STATUS     object
# SEX                object
# EDUCATION          object
# JOB                object
# TRAVEL TIME       float64
# USE                object
# MILES CLOCKED     float64
# CAR TYPE           object
# CAR AGE           float64
# CITY               object
# POSTAL CODE       float64
# dtype: object

# %%
df[df.isnull().sum()[df.isnull().sum()>0].index]
# Out:
#            INCOME MARITAL STATUS SEX    EDUCATION          JOB  TRAVEL TIME  \
# 0    125301.24250             No   F    Bachelors  Blue Collar    45.703013
# 1     50815.44531             No   M  High School          NaN    20.591628
# 2     62977.82416            NaN   F    Bachelors     Clerical    33.639949
# 3     77099.96624             No   F          NaN       Lawyer    15.415676
# 4    130794.57420             No   M  High School          NaN          NaN
# ..            ...            ...  ..          ...          ...          ...
# 298   15251.52473             No   M  High School     Clerical    31.315058
# 299   18408.39545             No   M  High School     Clerical    42.619118
# 300           NaN             No   M  High School     Clerical    36.533624
# 301           NaN            Yes   F  High School          NaN    60.884292
# 302       0.00000             No   M    Bachelors      Student    11.657483
#
# ...

# %%
sns.boxplot(x='INCOME',data=df);                 ##outliers present so impute null values with median

# %%
sns.boxplot(x='TRAVEL TIME',data=df);

# %%
sns.boxplot(x='MILES CLOCKED',data=df);                 ##outliers present so impute nyll values with median

# %%
sns.boxplot(x='CAR AGE',data=df);                 ##outliers present so impute nyll values with median

# %%
df['CITY'].mode()
# Out:
# 0      Houston
# 1    Las Vegas
# Name: CITY, dtype: object

# %%
df.groupby(by=['CITY','POSTAL CODE']).size()
# Out:
# CITY           POSTAL CODE
# Columbia       44123.0        28
# Houston        61701.0        39
# Las Vegas      44412.0        38
# Los Angeles    90049.0        19
# New Albany     47150.0        17
# New York City  12180.0        23
# Philadelphia   84057.0         1
# San Francisco  55106.0        27
# Seattle        78207.0        36
# Texas          42420.0        20
# Washington     11435.0        32
# dtype: int64

# %%
df.loc[7,'POSTAL CODE']=42420.0
df.loc[16,'POSTAL CODE']=42420.0
df.loc[299,'POSTAL CODE']=90049.0

# %%
df[df['POSTAL CODE'].isnull()]
# Out:
# Empty DataFrame
# Columns: [INDEX, INCOME, MARITAL STATUS, SEX, EDUCATION, JOB, TRAVEL TIME, USE, MILES CLOCKED, CAR TYPE, CAR AGE, CITY, POSTAL CODE]
# Index: []

# %%
df.isnull().sum()
# Out:
# INDEX              0
# INCOME            43
# MARITAL STATUS    28
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME       41
# USE               53
# MILES CLOCKED     25
# CAR TYPE          10
# CAR AGE           20
# CITY               6
# POSTAL CODE        0
# dtype: int64

# %%
df.loc[11,'CITY']='Texas'
df.loc[19,'CITY']='Texas'
df.loc[225,'CITY']='Columbia'
df.loc[254,'CITY']='Washington'
df.loc[285,'CITY']='Las Vegas'
df.loc[292,'CITY']='Las Vegas'

# %%
df[df['CITY'].isnull()]
# Out:
# Empty DataFrame
# Columns: [INDEX, INCOME, MARITAL STATUS, SEX, EDUCATION, JOB, TRAVEL TIME, USE, MILES CLOCKED, CAR TYPE, CAR AGE, CITY, POSTAL CODE]
# Index: []

# %%
df.isnull().sum()
# Out:
# INDEX              0
# INCOME            43
# MARITAL STATUS    28
# SEX                6
# EDUCATION         44
# JOB               46
# TRAVEL TIME       41
# USE               53
# MILES CLOCKED     25
# CAR TYPE          10
# CAR AGE           20
# CITY               0
# POSTAL CODE        0
# dtype: int64

# %%
## chnging the data types of postal-code from float to object(str) by .apply(str)

df['POSTAL CODE']=df['POSTAL CODE'].apply(str)

# %%
# df['postal code']=pd.categorical(df['postal code'])

# %%
df['EDUCATION'].mode()
# Out:
# 0    High School
# Name: EDUCATION, dtype: object

# %%
df['JOB'].value_counts()
# Out:
# Blue Collar     82
# Clerical        48
# Student         30
# Home Maker      27
# Professional    23
# Lawyer          15
# Manager         14
# Doctor           4
# Name: JOB, dtype: int64

# %%
df['EDUCATION'].value_counts()
# Out:
# High School    147
# Bachelors       54
# Masters         38
# PhD              6
# Name: EDUCATION, dtype: int64

# %%
df[df['JOB']=='Lawyer']
# Out:
#      INDEX        INCOME MARITAL STATUS  SEX EDUCATION     JOB  TRAVEL TIME  \
# 3        4   77099.96624             No    F       NaN  Lawyer    15.415676
# 13      14   63952.17766            Yes    F   Masters  Lawyer    49.576895
# 35      36   49848.95817             No    F   Masters  Lawyer    35.020971
# 46      47  111268.31170            NaN    F       NaN  Lawyer          NaN
# 55      56   61521.48327            Yes    F   Masters  Lawyer    40.501002
# 56      57  105554.35370             No    M   Masters  Lawyer    75.242975
# 85      72           NaN            Yes    M   Masters  Lawyer    55.319377
# 102     89           NaN            NaN    F   Masters  Lawyer    13.143433
# 134    121           NaN            NaN    F   Masters  Lawyer    51.405031
# 153    140   63889.85805            Yes    F   Masters  Lawyer          NaN
# 189    176   81294.19215            Yes    F       NaN  Lawyer    13.826072
# ...

# %%
df[df['JOB']=='Blue Collar']
# Out:
#      INDEX        INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0        1  125301.24250             No   F    Bachelors  Blue Collar
# 7        8           NaN            Yes   F  High School  Blue Collar
# 9       10           NaN            Yes   M  High School  Blue Collar
# 10      11   16988.72135             No   M  High School  Blue Collar
# 11      12           NaN             No   F  High School  Blue Collar
# ..     ...           ...            ...  ..          ...          ...
# 276    263   71197.08357             No   F  High School  Blue Collar
# 277    264   33644.06944             No   M  High School  Blue Collar
# 282    269   58504.00815             No   F    Bachelors  Blue Collar
# 291    278   78866.44664             No   F    Bachelors  Blue Collar
# 292    279   69475.68892            Yes   F  High School  Blue Collar
#
#      TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE       CITY  \
# ...

# %%
df.loc[df['JOB']=='Lawyer','EDUCATION']=df.loc[df['JOB']=='Lawyer','EDUCATION'].fillna('Masters')

# %%
df.loc[df['JOB']=='Manager','EDUCATION']=df.loc[df['JOB']=='Manager','EDUCATION'].fillna('Bachelors')

# %%
df.loc[df['JOB']=='Clerical','EDUCATION']=df.loc[df['JOB']=='Clerical','EDUCATION'].fillna('High School')

# %%
df.loc[df['JOB']=='Blue Collar','EDUCATION']=df.loc[df['JOB']=='Blue Collar','EDUCATION'].fillna('High School')

# %%
df[df['JOB']=='Clerical']
# Out:
#      INDEX        INCOME MARITAL STATUS  SEX    EDUCATION       JOB  \
# 2        3  62977.824160            NaN    F    Bachelors  Clerical
# 8        9           NaN            NaN    F          NaN  Clerical
# 14      15  24059.721570             No    M    Bachelors  Clerical
# 21      22  31773.103960            Yes    M  High School  Clerical
# 30      31  37579.711650            NaN    F  High School  Clerical
# 39      40  32936.110430             No    F  High School  Clerical
# 41      42  22181.484240             No    F          NaN  Clerical
# 44      45  30652.942300             No    F  High School  Clerical
# 49      50  30955.017860             No    F  High School  Clerical
# 51      52  44781.815860             No    F  High School  Clerical
# 52      53  30085.320610            Yes    M  High School  Clerical
# 53      54  32317.314210            NaN    M          NaN  Clerical
# 58      59   2954.141221             No    F  High School  Clerical
# ...

# %%
df.loc[df['JOB']=='Clerical','EDUCATION']=df.loc[df['JOB']=='Clerical','EDUCATION'].fillna('High School')

# %%
df.loc[df['JOB']=='Clerical','EDUCATION']=df.loc[df['JOB']=='Clerical','EDUCATION'].fillna('Bachelors')

# %%
df.loc[df['JOB']=='Blue Collar','EDUCATION']=df.loc[df['JOB']=='Blue Collar','EDUCATION'].fillna('High School')

# %%
df.loc[df['JOB']=='Home Maker','EDUCATION']=df.loc[df['JOB']=='Home Maker','EDUCATION'].fillna('High School')

# %%
df.loc[df['JOB']=='Professional','EDUCATION']=df.loc[df['JOB']=='Professional','EDUCATION'].fillna('Masters')

# %%
df.loc[df['JOB']=='Manager','EDUCATION']=df.loc[df['JOB']=='Manager','EDUCATION'].fillna('Bachelors')

# %%
df.loc[df['JOB']=='Student','EDUCATION']=df.loc[df['JOB']=='Student','EDUCATION'].fillna('Bachelors')

# %%
df.loc[df['EDUCATION']=='Bachelors','JOB']=df.loc[df['EDUCATION']=='Bachelors','JOB'].fillna('Manager')

# %%
df.loc[df['EDUCATION']=='Masters','JOB']=df.loc[df['EDUCATION']=='Masters','JOB'].fillna('Lawyer')

# %%
df.loc[df['EDUCATION']=='High School','JOB']=df.loc[df['EDUCATION']=='High School','JOB'].fillna('Home Maker')

# %%
df.loc[df['JOB']=='Blue Collar','EDUCATION']=df.loc[df['JOB']=='Blue Collar','EDUCATION'].fillna('High School')

# %%
df.loc[df['JOB']=='Lawyer','EDUCATION']=df.loc[df['JOB']=='Lawyer','EDUCATION'].fillna('Masters')

# %%
df.loc[df['JOB']=='Blue Collar','EDUCATION']=df.loc[df['JOB']=='Blue Collar','EDUCATION'].fillna('High School')

# %%
df.loc[df['JOB']=='Bachelors','EDUCATION']=df.loc[df['JOB']=='Bachelors','EDUCATION'].fillna('Professional')

# %%
df.loc[df['JOB']=='Blue Collar','EDUCATION']=df.loc[df['JOB']=='Blue Collar','EDUCATION'].fillna('High School')

# %%
df.loc[df['CAR TYPE']=='Pickup','JOB']=df.loc[df['CAR TYPE']=='Pickup','JOB'].fillna('Blue Collar')

# %%
df.loc[df['CAR TYPE']=='SUV','JOB']=df.loc[df['CAR TYPE']=='SUV','JOB'].fillna('Lawyer')

# %%
df.loc[df['CAR TYPE']=='Panel Truck','JOB']=df.loc[df['CAR TYPE']=='Panel Truck','JOB'].fillna('Blue Collar')

# %%
df.loc[df['CAR TYPE']=='Sports Car','JOB']=df.loc[df['CAR TYPE']=='Sports Car','JOB'].fillna('Bachelors')

# %%
df.loc[df['CAR TYPE']=='Van','JOB']=df.loc[df['CAR TYPE']=='Van','JOB'].fillna('Blue Collar')

# %%
df.isnull().sum()
# Out:
# INDEX              0
# INCOME            43
# MARITAL STATUS    28
# SEX                6
# EDUCATION          0
# JOB                0
# TRAVEL TIME       41
# USE               53
# MILES CLOCKED     25
# CAR TYPE          10
# CAR AGE           20
# CITY               0
# POSTAL CODE        0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 226

# %%
median1=df['INCOME'].median()
median2=df['TRAVEL TIME'].median()
median3=df['MILES CLOCKED'].median()
median4=df['CAR AGE'].median()

# %%
median1
# Out:
# 40171.535635

# %%
median2
# Out:
# 34.426445765

# %%
median3
# Out:
# 12845.0

# %%
median4
# Out:
# 6.0

# %%
df['INCOME'].replace(np.nan,median1,inplace=True)
df['TRAVEL TIME'].replace(np.nan,median2,inplace=True)
df['MILES CLOCKED'].replace(np.nan,median3,inplace=True)
df['CAR AGE'].replace(np.nan,median4,inplace=True)

# %%
mode1=df['MARITAL STATUS'].mode()[0]
mode2=df['SEX'].mode()[0]
mode3=df['EDUCATION'].mode()[0]
mode4=df['JOB'].mode()[0]
mode5=df['USE'].mode()[0]
mode6=df['CAR TYPE'].mode()[0]

# %%
df['MARITAL STATUS']=df['MARITAL STATUS'].replace(np.nan,mode1)
df['SEX']=df['SEX'].replace(np.nan,mode2)
df['EDUCATION']=df['EDUCATION'].replace(np.nan,mode3)
df['JOB']=df['JOB'].replace(np.nan,mode4)
df['USE']=df['USE'].replace(np.nan,mode5)
df['CAR TYPE']=df['CAR TYPE'].replace(np.nan,mode6)

# %%
df.isnull().sum()
# Out:
# INDEX             0
# INCOME            0
# MARITAL STATUS    0
# SEX               0
# EDUCATION         0
# JOB               0
# TRAVEL TIME       0
# USE               0
# MILES CLOCKED     0
# CAR TYPE          0
# CAR AGE           0
# CITY              0
# POSTAL CODE       0
# dtype: int64

# %%
df['EDUCATION'].mode()
# Out:
# 0    High School
# Name: EDUCATION, dtype: object

# %%
df[df['EDUCATION']=='High School']
# Out:
#      INDEX         INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 1        2   50815.445310             No   M  High School   Home Maker
# 4        5  130794.574200             No   M  High School   Home Maker
# 5        6   40171.535635             No   F  High School   Home Maker
# 6        7   87460.052690             No   M  High School      Manager
# 7        8   40171.535635            Yes   F  High School  Blue Collar
# ..     ...            ...            ...  ..          ...          ...
# 297    284       0.000000             No   F  High School      Student
# 298    285   15251.524730             No   M  High School     Clerical
# 299    286   18408.395450             No   M  High School     Clerical
# 300    287   40171.535635             No   M  High School     Clerical
# 301    288   40171.535635            Yes   F  High School   Home Maker
#
#      TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE       CITY  \
# ...

# %%
df.loc[3,'EDUCATION']='Masters'
df.loc[46,'EDUCATION']='Masters'
df.loc[189,'EDUCATION']='Masters'
df.loc[192,'EDUCATION']='Masters'

# %%
df[df['JOB']=='Manager']['INCOME'].mean()
# Out:
# 81373.57853631578

# %%
df[df['JOB']=='Home Maker']['INCOME'].mean()
# Out:
# 20540.677527090913

# %%
df.groupby(['CAR AGE','CAR TYPE']).size()
# Out:
# CAR AGE  CAR TYPE
# 1.0      Minivan        12
#          Panel Truck     5
#          Pickup         20
#          SUV            36
#          Sports Car     18
#                         ..
# 20.0     Minivan         1
#          Panel Truck     1
#          Pickup          1
#          SUV             2
#          Sports Car      1
# Length: 78, dtype: int64

# %%
df.groupby(['EDUCATION','JOB']).size()
# Out:
# EDUCATION     JOB
# Bachelors     Blue Collar     19
#               Clerical         6
#               Manager         13
#               Professional    16
#               Student          7
# High School   Blue Collar     67
#               Clerical        42
#               Home Maker      38
#               Manager          2
#               Professional     5
#               Student         23
# Masters       Home Maker       5
#               Lawyer          34
#               Manager          3
#               Professional     2
# PhD           Doctor           4
#               Home Maker       1
#               Manager          1
# Professional  Bachelors        1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# INDEX             0
# INCOME            0
# MARITAL STATUS    0
# SEX               0
# EDUCATION         0
# JOB               0
# TRAVEL TIME       0
# USE               0
# MILES CLOCKED     0
# CAR TYPE          0
# CAR AGE           0
# CITY              0
# POSTAL CODE       0
# dtype: int64

# %% [markdown]
# # Outlier Treatment

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range=Q1-(1.5*IQR)
    upper_range=Q3+(1.5*IQR)
    return lower_range,upper_range

# %%
lr_income,ur_income=remove_outlier(df['INCOME'])

# %%
print('lr_income=',lr_income,'\n','ur_income=',ur_income)
# Out:
# lr_income= -41106.659100000004
#  ur_income= 126887.76834000001

# %%
lr_income,ur_income=remove_outlier(df['INCOME'])
df['INCOME']=np.where(df['INCOME']>ur_income,ur_income,df['INCOME'])
df['INCOME']=np.where(df['INCOME']<lr_income,lr_income,df['INCOME'])

lr_miles,ur_miles=remove_outlier(df['MILES CLOCKED'])
df['MILES CLOCKED']=np.where(df['MILES CLOCKED']>ur_miles,ur_miles,df['MILES CLOCKED'])
df['MILES CLOCKED']=np.where(df['MILES CLOCKED']<lr_miles,lr_miles,df['MILES CLOCKED'])


lr_travel,ur_travel=remove_outlier(df['TRAVEL TIME'])
df['TRAVEL TIME']=np.where(df['TRAVEL TIME']>ur_travel,ur_travel,df['TRAVEL TIME'])
df['TRAVEL TIME']=np.where(df['TRAVEL TIME']<lr_travel,lr_travel,df['TRAVEL TIME'])

# %%
sns.boxplot(x='INCOME',data=df);

# %%
sns.boxplot(x='MILES CLOCKED',data=df);

# %%
sns.boxplot(x='TRAVEL TIME',data=df);

# %% [markdown]
# ## DATA Scaling ( on numerical variables)

# %% [markdown]
# ## 1) Standard Scaling  (-3 to +3)

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_scale=StandardScaler()
std_scale
# Out:
# StandardScaler()

# %%
df_std=df.copy()
df_std.head()
# Out:
#    INDEX        INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0      1  125301.24250             No   F    Bachelors  Blue Collar
# 1      2   50815.44531             No   M  High School  Blue Collar
# 2      3   62977.82416             No   F    Bachelors     Clerical
# 3      4   77099.96624             No   F      Masters       Lawyer
# 4      5  126887.76834             No   M  High School  Blue Collar
#
#    TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE   CITY  \
# 0    45.703013  Commercial        17430.0   Sports Car      7.0  Texas
# 1    20.591628     Private        18930.0      Minivan      1.0  Texas
# 2    33.639949     Private        12845.0          SUV      1.0  Texas
# 3    15.415676     Private        18300.0   Sports Car     11.0  Texas
# 4    34.426446  Commercial        28340.0  Panel Truck     10.0  Texas
#
#   POSTAL CODE
# 0     42420.0
# 1     42420.0
# 2     42420.0
# 3     42420.0
# 4     42420.0

# %%
df_std['INCOME']=std_scale.fit_transform(df_std[['INCOME']])
df_std['TRAVEL TIME']=std_scale.fit_transform(df_std[['TRAVEL TIME']])
df_std['MILES CLOCKED']=std_scale.fit_transform(df_std[['MILES CLOCKED']])
df_std['CAR AGE']=std_scale.fit_transform(df_std[['CAR AGE']])

# %%
df_std.head()
# Out:
#    INDEX    INCOME MARITAL STATUS SEX    EDUCATION          JOB  TRAVEL TIME  \
# 0      1  2.344391             No   F    Bachelors  Blue Collar     0.832200
# 1      2  0.139393             No   M  High School  Blue Collar    -0.991124
# 2      3  0.499435             No   F    Bachelors     Clerical    -0.043693
# 3      4  0.917492             No   F      Masters       Lawyer    -1.366947
# 4      5  2.391357             No   M  High School  Blue Collar     0.013415
#
#           USE  MILES CLOCKED     CAR TYPE   CAR AGE   CITY POSTAL CODE  \
# 0  Commercial       0.535034   Sports Car  0.137267  Texas     42420.0
# 1     Private       0.754768      Minivan -1.052842  Texas     42420.0
# 2     Private      -0.136620          SUV -1.052842  Texas     42420.0
# 3     Private       0.662480   Sports Car  0.930674  Texas     42420.0
# 4  Commercial       2.133234  Panel Truck  0.732322  Texas     42420.0
#
#    TRAVEL TIME\t
# 0       0.832200
# 1      -0.991124
# 2      -0.043693
# ...

# %% [markdown]
# ## 2) Min Max Scaler  (0 to 1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df_minmax=df.copy()
df_minmax.head()
# Out:
#    INDEX        INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0      1  125301.24250             No   F    Bachelors  Blue Collar
# 1      2   50815.44531             No   M  High School  Blue Collar
# 2      3   62977.82416             No   F    Bachelors     Clerical
# 3      4   77099.96624             No   F      Masters       Lawyer
# 4      5  126887.76834             No   M  High School  Blue Collar
#
#    TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE   CITY  \
# 0    45.703013  Commercial        17430.0   Sports Car      7.0  Texas
# 1    20.591628     Private        18930.0      Minivan      1.0  Texas
# 2    33.639949     Private        12845.0          SUV      1.0  Texas
# 3    15.415676     Private        18300.0   Sports Car     11.0  Texas
# 4    34.426446  Commercial        28340.0  Panel Truck     10.0  Texas
#
#   POSTAL CODE
# 0     42420.0
# 1     42420.0
# 2     42420.0
# 3     42420.0
# 4     42420.0

# %%
minmax=MinMaxScaler()
minmax
# Out:
# MinMaxScaler()

# %%
df_minmax['INCOME']=minmax.fit_transform(df_minmax[['INCOME']])
df_minmax['TRAVEL TIME']=minmax.fit_transform(df_minmax[['TRAVEL TIME']])
df_minmax['MILES CLOCKED']=minmax.fit_transform(df_minmax[['MILES CLOCKED']])
df_minmax['CAR AGE']=minmax.fit_transform(df_minmax[['CAR AGE']])

# %%
df_minmax.head()
# Out:
#    INDEX    INCOME MARITAL STATUS SEX    EDUCATION          JOB  TRAVEL TIME  \
# 0      1  0.987497             No   F    Bachelors  Blue Collar     0.649445
# 1      2  0.400476             No   M  High School  Blue Collar     0.248775
# 2      3  0.496327             No   F    Bachelors     Clerical     0.456970
# 3      4  0.607623             No   F      Masters       Lawyer     0.166189
# 4      5  1.000000             No   M  High School  Blue Collar     0.469519
#
#           USE  MILES CLOCKED     CAR TYPE   CAR AGE   CITY POSTAL CODE
# 0  Commercial       0.507083   Sports Car  0.315789  Texas     42420.0
# 1     Private       0.554830      Minivan  0.000000  Texas     42420.0
# 2     Private       0.361133          SUV  0.000000  Texas     42420.0
# 3     Private       0.534776   Sports Car  0.526316  Texas     42420.0
# 4  Commercial       0.854369  Panel Truck  0.473684  Texas     42420.0

# %%
df_minmax.drop('INDEX',axis=1,inplace=True)

# %%
df_minmax.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3) Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
df_robust=df.copy()
df_robust.head()
# Out:
#    INDEX        INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0      1  125301.24250             No   F    Bachelors  Blue Collar
# 1      2   50815.44531             No   M  High School  Blue Collar
# 2      3   62977.82416             No   F    Bachelors     Clerical
# 3      4   77099.96624             No   F      Masters       Lawyer
# 4      5  126887.76834             No   M  High School  Blue Collar
#
#    TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE   CITY  \
# 0    45.703013  Commercial        17430.0   Sports Car      7.0  Texas
# 1    20.591628     Private        18930.0      Minivan      1.0  Texas
# 2    33.639949     Private        12845.0          SUV      1.0  Texas
# 3    15.415676     Private        18300.0   Sports Car     11.0  Texas
# 4    34.426446  Commercial        28340.0  Panel Truck     10.0  Texas
#
#   POSTAL CODE
# 0     42420.0
# 1     42420.0
# 2     42420.0
# 3     42420.0
# 4     42420.0

# %%
robust=RobustScaler()
robust
# Out:
# RobustScaler()

# %%
df_robust['INCOME']=robust.fit_transform(df_robust[['INCOME']])
df_robust['TRAVEL TIME']=robust.fit_transform(df_robust[['TRAVEL TIME']])
df_robust['MILES CLOCKED']=robust.fit_transform(df_robust[['MILES CLOCKED']])
df_robust['CAR AGE']=robust.fit_transform(df_robust[['CAR AGE']])

# %%
df_robust.head()
# Out:
#    INDEX    INCOME MARITAL STATUS SEX    EDUCATION          JOB  TRAVEL TIME  \
# 0      1  2.026965             No   F    Bachelors  Blue Collar     0.675123
# 1      2  0.253435             No   M  High School  Blue Collar    -0.828285
# 2      3  0.543025             No   F    Bachelors     Clerical    -0.047087
# 3      4  0.879278             No   F      Masters       Lawyer    -1.138167
# 4      5  2.064741             No   M  High School  Blue Collar     0.000000
#
#           USE  MILES CLOCKED     CAR TYPE   CAR AGE   CITY POSTAL CODE
# 0  Commercial       0.462664   Sports Car  0.111111  Texas     42420.0
# 1     Private       0.614026      Minivan -0.555556  Texas     42420.0
# 2     Private       0.000000          SUV -0.555556  Texas     42420.0
# 3     Private       0.550454   Sports Car  0.555556  Texas     42420.0
# 4  Commercial       1.563572  Panel Truck  0.444444  Texas     42420.0

# %%
# here we do not need to apply robust scaler. bcz the data is normalised state. 
# robust scaler is applied without treating outliers.

# %% [markdown]
# # Variable Transformation (on categorical variable)

# %% [markdown]
# ## 1) One Hot EnCoding

# %%
df_ohe=df.copy()
df_ohe
# Out:
#      INDEX         INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0        1  125301.242500             No   F    Bachelors  Blue Collar
# 1        2   50815.445310             No   M  High School  Blue Collar
# 2        3   62977.824160             No   F    Bachelors     Clerical
# 3        4   77099.966240             No   F      Masters       Lawyer
# 4        5  126887.768340             No   M  High School  Blue Collar
# ..     ...            ...            ...  ..          ...          ...
# 298    285   15251.524730             No   M  High School     Clerical
# 299    286   18408.395450             No   M  High School     Clerical
# 300    287   40171.535635             No   M  High School     Clerical
# 301    288   40171.535635            Yes   F  High School  Blue Collar
# 302    289       0.000000             No   M    Bachelors      Student
#
#      TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE       CITY  \
# ...

# %%
df_ohe=pd.get_dummies(df_ohe,drop_first=True)
df_ohe
# Out:
#      INDEX         INCOME  TRAVEL TIME  MILES CLOCKED  CAR AGE  \
# 0        1  125301.242500    45.703013        17430.0      7.0
# 1        2   50815.445310    20.591628        18930.0      1.0
# 2        3   62977.824160    33.639949        12845.0      1.0
# 3        4   77099.966240    15.415676        18300.0     11.0
# 4        5  126887.768340    34.426446        28340.0     10.0
# ..     ...            ...          ...            ...      ...
# 298    285   15251.524730    31.315058         3030.0      1.0
# 299    286   18408.395450    42.619118         7440.0      1.0
# 300    287   40171.535635    36.533624         7660.0      6.0
# 301    288   40171.535635    60.884292        19550.0      1.0
# 302    289       0.000000    11.657483        19940.0      7.0
#
#      MARITAL STATUS_Yes  SEX_M  EDUCATION_High School  EDUCATION_Masters  \
# 0                     0      0                      0                  0
# ...

# %% [markdown]
# ## 2) Label EnCoding

# %%
df_le=df.copy()
df_le
# Out:
#      INDEX         INCOME MARITAL STATUS SEX    EDUCATION          JOB  \
# 0        1  125301.242500             No   F    Bachelors  Blue Collar
# 1        2   50815.445310             No   M  High School  Blue Collar
# 2        3   62977.824160             No   F    Bachelors     Clerical
# 3        4   77099.966240             No   F      Masters       Lawyer
# 4        5  126887.768340             No   M  High School  Blue Collar
# ..     ...            ...            ...  ..          ...          ...
# 298    285   15251.524730             No   M  High School     Clerical
# 299    286   18408.395450             No   M  High School     Clerical
# 300    287   40171.535635             No   M  High School     Clerical
# 301    288   40171.535635            Yes   F  High School  Blue Collar
# 302    289       0.000000             No   M    Bachelors      Student
#
#      TRAVEL TIME         USE  MILES CLOCKED     CAR TYPE  CAR AGE       CITY  \
# ...

# %%
for feature in df_le.columns:
    df_le[feature]=pd.Categorical(df_le[feature]).codes

# %%
df_le.head()
# Out:
#    INDEX  INCOME  MARITAL STATUS  SEX  EDUCATION  JOB  TRAVEL TIME  USE  \
# 0      0     206               0    0          0    0          188    0
# 1      1     120               0    1          1    0           44    1
# 2      2     148               0    0          0    1          112    1
# 3      3     172               0    0          2    4           29    1
# 4      4     207               0    1          1    0          119    0
#
#    MILES CLOCKED  CAR TYPE  CAR AGE  CITY  POSTAL CODE
# 0            162         4        5     9            2
# 1            178         0        0     9            2
# 2            113         3        0     9            2
# 3            173         4        9     9            2
# 4            230         1        8     9            2

# %%
df_le['EDUCATION'].value_counts()
# Out:
# 1    179
# 0     61
# 2     43
# 3      6
# Name: EDUCATION, dtype: int64

# %%
# Refer the 1st and the 4th line for the mappings

# %%
for feature in df_le.columns:
    if df_le[feature].dtypes=='object':
        print('feature',feature)
        print(pd.Categorical(df_le[feature].unique()))
        print(pd.Categorical(df_le[feature].unique()).codes)
        df_le[feature]=pd.Categorical(df_le[feature]).codes
# Out:
# feature MARITAL STATUS
# ['No', 'Yes']
# Categories (2, object): ['No', 'Yes']
# [0 1]
# feature SEX
# ['F', 'M']
# Categories (2, object): ['F', 'M']
# [0 1]
# feature EDUCATION
# ['Bachelors', 'High School', 'Masters', 'PhD']
# Categories (4, object): ['Bachelors', 'High School', 'Masters', 'PhD']
# [0 1 2 3]
# feature JOB
# ['Blue Collar', 'Clerical', 'Lawyer', 'Home Maker', 'Manager', 'Professional', 'Student', 'Doctor']
# Categories (8, object): ['Blue Collar', 'Clerical', 'Doctor', 'Home Maker', 'Lawyer', 'Manager', 'Professional', 'Student']
# [0 1 4 3 5 6 7 2]
# feature USE
# ['Commercial', 'Private']
# Categories (2, object): ['Commercial', 'Private']
# [0 1]
# feature CAR TYPE
# ['Sports Car', 'Minivan', 'SUV', 'Panel Truck', 'Pickup', 'Van']
# Categories (6, object): ['Minivan', 'Panel Truck', 'Pickup', 'SUV', 'Sports Car', 'Van']
# [4 0 3 1 2 5]
# feature CITY
# ...
