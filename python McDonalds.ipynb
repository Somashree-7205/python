# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings("ignore")

# %%
df=pd.read_csv('Mcdonald .csv')

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
df.shape
# Out:
# (260, 24)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe(include='all')
# Out:
#             Category          Item  Serving Size     Calories  \
# count            260           260           260   260.000000
# unique             9           260           107          NaN
# top     Coffee & Tea  Egg McMuffin  16 fl oz cup          NaN
# freq              95             1            45          NaN
# mean             NaN           NaN           NaN   368.269231
# std              NaN           NaN           NaN   240.269886
# min              NaN           NaN           NaN     0.000000
# 25%              NaN           NaN           NaN   210.000000
# 50%              NaN           NaN           NaN   340.000000
# 75%              NaN           NaN           NaN   500.000000
# max              NaN           NaN           NaN  1880.000000
#
#         Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count          260.000000  260.000000                 260.000000
# unique                NaN         NaN                        NaN
# ...

# %%
##find out the number of categories in each variety?

df['Category'].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %% [markdown]
# ### 1) Make a Pie Chart displaying the distribution of Category.

# %%
##find out the number of categories in each variety? make a pie chart displaying the distribution of categories?

df['Category'].value_counts(normalize=True)*100
# Out:
# Coffee & Tea          36.538462
# Breakfast             16.153846
# Smoothies & Shakes    10.769231
# Chicken & Fish        10.384615
# Beverages             10.384615
# Beef & Pork            5.769231
# Snacks & Sides         5.000000
# Desserts               2.692308
# Salads                 2.307692
# Name: Category, dtype: float64

# %%
df['Category'].value_counts().index
# Out:
# Index(['Coffee & Tea', 'Breakfast', 'Smoothies & Shakes', 'Chicken & Fish',
#        'Beverages', 'Beef & Pork', 'Snacks & Sides', 'Desserts', 'Salads'],
#       dtype='object')

# %%
plt.pie(df['Category'].value_counts(normalize=True),labels=df['Category'].value_counts().index,autopct='%1.1f%%');

# %% [markdown]
# ### 2) find out the items which have less than  1 of total fat ???

# %%
df1=df[df['Total Fat']>1].sort_values(by='Total Fat',ascending=False).head(10)

# %%
plt.figure(figsize=(12,4))
sns.boxplot(x='Total Fat',y='Category',data=df1,color='pink');

# %% [markdown]
# ### 3)  find out the top  5 breakfast items which have more protein??

# %%
df1=df[df['Category']=='Breakfast']

# %%
df1.sort_values(by='Protein',ascending=False,inplace=True)

# %%
plt.figure(figsize=(10,3))

sns.barplot(x='Item',y='Protein',data=df1,ci=None);

plt.xticks(rotation=90);

# %% [markdown]
# ### 4) find out the top 5 breakfast items which have more calories??

# %%
df[df['Category']=='Breakfast'].sort_values(by='Calories',ascending=False).head(5)
# Out:
#      Category                                               Item  \
# 32  Breakfast        Big Breakfast with Hotcakes (Large Biscuit)
# 31  Breakfast      Big Breakfast with Hotcakes (Regular Biscuit)
# 34  Breakfast  Big Breakfast with Hotcakes and Egg Whites (La...
# 33  Breakfast  Big Breakfast with Hotcakes and Egg Whites (Re...
# 28  Breakfast                      Big Breakfast (Large Biscuit)
#
#        Serving Size  Calories  Calories from Fat  Total Fat  \
# 32  15.3 oz (434 g)      1150                540       60.0
# 31  14.8 oz (420 g)      1090                510       56.0
# 34  15.4 oz (437 g)      1050                450       50.0
# 33  14.9 oz (423 g)       990                410       46.0
# 28    10 oz (283 g)       800                470       52.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 32                         93           20.0                            100
# ...

# %%
df2=df[df['Category']=='Breakfast']

# %%
df2.sort_values(by='Calories',ascending=False,inplace=True)

# %%
plt.figure(figsize=(10,3))

sns.barplot(x='Item',y='Calories',data=df2,ci=None);

plt.xticks(rotation=90);

# %% [markdown]
# ### 5) findout the top 10 items in Coffee & Tea category which have more sugars

# %%
df4=df[df['Category']=='Coffee & Tea']

# %%
df5=df4.sort_values(by='Sugars',ascending=False).head(10)

# %%
plt.figure(figsize=(10,3))

sns.barplot(x='Item',y='Sugars',data=df5,ci=None);

plt.xticks(rotation=90);

# %% [markdown]
# ### 6) Can we say there is a linear relationship between Calory & Total fat over different category?

# %%
plt.figure(figsize=(4,3))

sns.lmplot(x='Calories',y='Total Fat',data=df,hue='Category',ci=None);

# %% [markdown]
# ### 7) Find a linear relationship between Sodium & Calcium  over different category?

# %%
plt.figure(figsize=(4,3))

sns.lmplot(x='Sodium (% Daily Value)',y='Calcium (% Daily Value)',data=df,hue='Category',ci=None);

# %% [markdown]
# ### 8) Find a relationship between total fat & Cholesterol over different category?

# %%
sns.scatterplot(x='Total Fat',y='Cholesterol',data=df,hue='Category');

# %% [markdown]
# ### 9) Find a relationship between vit C & Calcium over different category?

# %%
sns.scatterplot(x='Vitamin C (% Daily Value)',y='Calcium (% Daily Value)',data=df,hue='Category');

# %% [markdown]
# ### 10) Find a relationship between vit C & vit A over different category?

# %%
sns.scatterplot(x='Vitamin A (% Daily Value)',y='Vitamin C (% Daily Value)',data=df,hue='Category');
