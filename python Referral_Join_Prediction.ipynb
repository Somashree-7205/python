# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings ("ignore")

# %%
df=pd.read_csv('Referral_Join_Prediction.csv')
df
# Out:
#      referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 0              1            28                    5.0                   Delhi
# 1              2            26                    3.0                    Pune
# 2              3            23                    2.0                  Mumbai
# 3              4            29                    6.0               Bangalore
# 4              5            26                    3.0                  Mumbai
# ..           ...           ...                    ...                     ...
# 494          495            21                    1.0                    Pune
# 495          496            21                    1.0                  Mumbai
# 496          497            29                    7.0                  Mumbai
# 497          498            30                    7.0                  Mumbai
# 498          499            30                    8.0               Bangalore
#
# ...

# %%
df.head()
# Out:
#    referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 0            1            28                    5.0                   Delhi
# 1            2            26                    3.0                    Pune
# 2            3            23                    2.0                  Mumbai
# 3            4            29                    6.0               Bangalore
# 4            5            26                    3.0                  Mumbai
#
#    referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 0                      106                  89.0                   72
# 1                       65                  63.0                   77
# 2                       45                  92.0                   85
# 3                      126                  60.0                   95
# 4                       65                  92.0                   70
#
#    referral_graduation_marks  referral_post_grad_marks referral_gender  \
# ...

# %%
df.shape
# Out:
# (499, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   referral_id                          499 non-null    int64
#  1   referral_age                         499 non-null    int64
#  2   referral_exp_in_years                499 non-null    float64
#  3   referral_preferred_city              499 non-null    object
#  4   referral_current_salary              499 non-null    int64
#  5   referral_10_th_marks                 498 non-null    float64
#  6   referral_12th_marks                  499 non-null    int64
#  7   referral_graduation_marks            498 non-null    float64
#  8   referral_post_grad_marks             498 non-null    float64
#  9   referral_gender                      499 non-null    object
#  10  referral_expected_sal                497 non-null    float64
# ...

# %%
df.describe(include='all')
# Out:
#         referral_id  referral_age  referral_exp_in_years  \
# count    499.000000    499.000000             499.000000
# unique          NaN           NaN                    NaN
# top             NaN           NaN                    NaN
# freq            NaN           NaN                    NaN
# mean     250.000000     27.020040               4.053307
# std      144.193157      2.811979               2.609814
# min        1.000000     20.000000               1.000000
# 25%      125.500000     25.000000               2.000000
# 50%      250.000000     27.000000               4.000000
# 75%      374.500000     29.000000               6.000000
# max      499.000000     65.000000              42.000000
#
#        referral_preferred_city  referral_current_salary  referral_10_th_marks  \
# count                      499               499.000000            498.000000
# unique                       4                      NaN                   NaN
# ...

# %%
df.isnull().sum()
# Out:
# referral_id                             0
# referral_age                            0
# referral_exp_in_years                   0
# referral_preferred_city                 0
# referral_current_salary                 0
# referral_10_th_marks                    1
# referral_12th_marks                     0
# referral_graduation_marks               1
# referral_post_grad_marks                1
# referral_gender                         0
# referral_expected_sal                   2
# referral_aptitude_numerical_score       3
# referral_aptitude_verbal_score         10
# referral_aptitude_reasoning_score       4
# referral_Management_Interview_score     1
# referral_HR_Interview_score             0
# Salary offered                          0
# Emp_Salary_Grade                        0
# Joined                                  0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 23

# %%
df.dropna().shape
# Out:
# (478, 19)

# %%
dups=df.duplicated()
df[dups]
# Out:
# Empty DataFrame
# Columns: [referral_id, referral_age, referral_exp_in_years, referral_preferred_city, referral_current_salary, referral_10_th_marks, referral_12th_marks, referral_graduation_marks, referral_post_grad_marks, referral_gender, referral_expected_sal, referral_aptitude_numerical_score, referral_aptitude_verbal_score, referral_aptitude_reasoning_score, referral_Management_Interview_score, referral_HR_Interview_score, Salary offered, Emp_Salary_Grade, Joined]
# Index: []

# %%
##MISSING VALUE TREATMENT

df[df.isnull().sum()[df.isnull().sum()>0].index].dtypes
# Out:
# referral_10_th_marks                   float64
# referral_graduation_marks              float64
# referral_post_grad_marks               float64
# referral_expected_sal                  float64
# referral_aptitude_numerical_score       object
# referral_aptitude_verbal_score         float64
# referral_aptitude_reasoning_score       object
# referral_Management_Interview_score    float64
# dtype: object

# %%
df[df.isnull().sum()[df.isnull().sum()>0].index]
# Out:
#      referral_10_th_marks  referral_graduation_marks  \
# 0                    89.0                       87.0
# 1                    63.0                       94.0
# 2                    92.0                       84.0
# 3                    60.0                       95.0
# 4                    92.0                       80.0
# ..                    ...                        ...
# 494                  81.0                       77.0
# 495                  74.0                       67.0
# 496                  94.0                       89.0
# 497                  64.0                       61.0
# 498                  67.0                       81.0
#
#      referral_post_grad_marks  referral_expected_sal  \
# 0                        83.0                  123.0
# 1                        85.0                   83.0
# 2                        72.0                   62.0
# 3                        67.0                  146.0
# 4                        92.0                   83.0
# ...

# %%
print(df[df.isnull().any(axis=1)])
# Out:
#      referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 10            11            22                    1.0                    Pune
# 11            12            22                    1.0               Bangalore
# 62            63            30                    7.0                   Delhi
# 84            85            28                    5.0                    Pune
# 92            93            27                    4.0               Bangalore
# 112          113            27                    4.0               Bangalore
# 125          126            29                    6.0                  Mumbai
# 160          161            26                    3.0                  Mumbai
# 162          163            28                    5.0                  Mumbai
# 238          239            24                    1.0               Bangalore
# 255          256            25                    2.0                  Mumbai
# ...

# %%
df.isnull().sum()
# Out:
# referral_id                             0
# referral_age                            0
# referral_exp_in_years                   0
# referral_preferred_city                 0
# referral_current_salary                 0
# referral_10_th_marks                    1
# referral_12th_marks                     0
# referral_graduation_marks               1
# referral_post_grad_marks                1
# referral_gender                         0
# referral_expected_sal                   2
# referral_aptitude_numerical_score       3
# referral_aptitude_verbal_score         10
# referral_aptitude_reasoning_score       4
# referral_Management_Interview_score     1
# referral_HR_Interview_score             0
# Salary offered                          0
# Emp_Salary_Grade                        0
# Joined                                  0
# dtype: int64

# %%
sns.boxplot(x='referral_age',data=df);

# %%
sns.boxplot(x='referral_exp_in_years',data=df);

# %%
sns.boxplot(x='referral_current_salary',data=df);

# %%
sns.boxplot(x='referral_10_th_marks',data=df);

# %%
sns.boxplot(x='referral_12th_marks',data=df);

# %%
sns.boxplot(x='referral_graduation_marks',data=df);

# %%
sns.boxplot(x='referral_expected_sal',data=df);

# %%
sns.boxplot(x='referral_HR_Interview_score',data=df);

# %%
sns.boxplot(x='Salary offered',data=df);

# %%
df['referral_aptitude_numerical_score'].replace("?", 40.00, inplace=True)

# %%
df['referral_aptitude_reasoning_score'].replace("?", 32.17, inplace=True)

# %%
df['referral_aptitude_numerical_score'] = df['referral_aptitude_numerical_score'].astype(float)

# %%
df['referral_aptitude_reasoning_score'] = df['referral_aptitude_reasoning_score'].astype(float)

# %%
df.loc[df['referral_current_salary']==26,'referral_expected_sal']=df.loc[df['referral_current_salary']==26,'referral_expected_sal'].fillna(43.0)

# %%
df.loc[df['referral_current_salary']==106,'referral_expected_sal']=df.loc[df['referral_current_salary']==106,'referral_expected_sal'].fillna(123.0)

# %%
df[df['referral_current_salary']==106]
# Out:
#      referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 0              1            28                    5.0                   Delhi
# 20            21            27                    5.0                  Mumbai
# 26            27            28                    5.0               Bangalore
# 35            36            28                    4.0                    Pune
# 51            52            28                    5.0                  Mumbai
# ..           ...           ...                    ...                     ...
# 465          466            28                    5.0               Bangalore
# 475          476            28                    5.0                  Mumbai
# 479          480            28                    5.0                    Pune
# 484          485            28                    5.0                   Delhi
# 485          486            28                    5.0                   Delhi
#
# ...

# %%
df[df['referral_10_th_marks'].isnull()]
# Out:
#      referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 112          113            27                    4.0               Bangalore
#
#      referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 112                       85                   NaN                   92
#
#      referral_graduation_marks  referral_post_grad_marks referral_gender  \
# 112                       85.0                      70.0          Female
#
#      referral_expected_sal  referral_aptitude_numerical_score  \
# 112                  103.0                               8.26
#
#      referral_aptitude_verbal_score  referral_aptitude_reasoning_score  \
# 112                            40.0                              42.17
#
#      referral_Management_Interview_score  referral_HR_Interview_score  \
# 112                                  7.0                            6
#
#      Salary offered Emp_Salary_Grade Joined
# 112             101              EL0    Yes

# %%
df.loc[df['referral_12th_marks']==92,'referral_10_th_marks']=df.loc[df['referral_12th_marks']==92,'referral_10_th_marks'].fillna(77.0)

# %%
df[df['referral_graduation_marks'].isnull()]
# Out:
#     referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 92           93            27                    4.0               Bangalore
#
#     referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 92                       85                  88.0                   78
#
#     referral_graduation_marks  referral_post_grad_marks referral_gender  \
# 92                        NaN                      86.0          Female
#
#     referral_expected_sal  referral_aptitude_numerical_score  \
# 92                  103.0                              12.17
#
#     referral_aptitude_verbal_score  referral_aptitude_reasoning_score  \
# 92                           31.74                              37.39
#
#     referral_Management_Interview_score  referral_HR_Interview_score  \
# 92                                  6.0                           10
#
#     Salary offered Emp_Salary_Grade Joined
# 92             101              EL0     No

# %%
df.loc[df['referral_12th_marks']==78,'referral_graduation_marks']=df.loc[df['referral_12th_marks']==78,'referral_graduation_marks'].fillna(80.0)

# %%
df[df['referral_post_grad_marks'].isnull()]
# Out:
#      referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 489          490            26                    3.0               Bangalore
#
#      referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 489                       65                  83.0                   83
#
#      referral_graduation_marks  referral_post_grad_marks referral_gender  \
# 489                       83.0                       NaN          Female
#
#      referral_expected_sal  referral_aptitude_numerical_score  \
# 489                  100.0                              33.48
#
#      referral_aptitude_verbal_score  referral_aptitude_reasoning_score  \
# 489                           12.17                              20.43
#
#      referral_Management_Interview_score  referral_HR_Interview_score  \
# 489                                  3.0                            3
#
#      Salary offered Emp_Salary_Grade Joined
# 489              80              EL0     No

# %%
df.loc[df['referral_graduation_marks']==83.0,'referral_post_grad_marks']=df.loc[df['referral_graduation_marks']==83.0,'referral_post_grad_marks'].fillna(78.0)

# %%
df.isnull().sum()
# Out:
# referral_id                             0
# referral_age                            0
# referral_exp_in_years                   0
# referral_preferred_city                 0
# referral_current_salary                 0
# referral_10_th_marks                    0
# referral_12th_marks                     0
# referral_graduation_marks               0
# referral_post_grad_marks                0
# referral_gender                         0
# referral_expected_sal                   0
# referral_aptitude_numerical_score       3
# referral_aptitude_verbal_score         10
# referral_aptitude_reasoning_score       4
# referral_Management_Interview_score     1
# referral_HR_Interview_score             0
# Salary offered                          0
# Emp_Salary_Grade                        0
# Joined                                  0
# dtype: int64

# %%
df[df['referral_aptitude_verbal_score'].isnull()]
# Out:
#      referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 10            11            22                    1.0                    Pune
# 62            63            30                    7.0                   Delhi
# 162          163            28                    5.0                  Mumbai
# 238          239            24                    1.0               Bangalore
# 272          273            24                    1.0               Bangalore
# 297          298            25                    2.0                  Mumbai
# 405          406            26                    3.0                  Mumbai
# 409          410            25                    2.0                  Mumbai
# 441          442            24                    1.0                  Mumbai
# 476          477            29                    6.0                  Mumbai
#
#      referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# ...

# %%
median2=df['referral_aptitude_verbal_score'].median()
median2
# Out:
# 20.87

# %%
df['referral_aptitude_verbal_score'].replace(np.nan,median2,inplace=True)

# %%
df[df['referral_aptitude_reasoning_score'].isnull()]
# Out:
#      referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 160          161            26                    3.0                  Mumbai
# 294          295            27                    4.0                  Mumbai
# 297          298            25                    2.0                  Mumbai
# 401          402            29                    6.0                  Mumbai
#
#      referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 160                       65                  78.0                   67
# 294                       85                  75.0                   68
# 297                       45                  89.0                   88
# 401                      126                  61.0                   82
#
#      referral_graduation_marks  referral_post_grad_marks referral_gender  \
# 160                       72.0                      72.0            Male
# ...

# %%
mode3=df['referral_aptitude_reasoning_score'].mode()[0]
mode3
# Out:
# 6.52

# %%
df['referral_aptitude_reasoning_score']=df['referral_aptitude_reasoning_score'].replace(np.nan,mode3)

# %%
mode4=df['referral_aptitude_numerical_score'].mode()[0]
mode5=df['referral_Management_Interview_score'].mode()[0]

# %%
df['referral_aptitude_numerical_score']=df['referral_aptitude_numerical_score'].replace(np.nan,mode4)
df['referral_Management_Interview_score']=df['referral_Management_Interview_score'].replace(np.nan,mode5)

# %% [markdown]
# ## Outlier Treatment

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range=Q1-(1.5*IQR)
    upper_range=Q3+(1.5*IQR)
    return lower_range,upper_range

# %%
lr_age,ur_age=remove_outlier(df['referral_age'])
df['referral_age']=np.where(df['referral_age']>ur_age,ur_age,df['referral_age'])
df['referral_age']=np.where(df['referral_age']<lr_age,lr_age,df['referral_age'])

lr_exp_in_yrs,ur_exp_in_yrs=remove_outlier(df['referral_exp_in_years'])
df['referral_exp_in_years']=np.where(df['referral_exp_in_years']>ur_exp_in_yrs,ur_exp_in_yrs,df['referral_exp_in_years'])
df['referral_exp_in_years']=np.where(df['referral_exp_in_years']<lr_exp_in_yrs,lr_exp_in_yrs,df['referral_exp_in_years'])

lr_curr_sal,ur_curr_sal=remove_outlier(df['referral_current_salary'])
df['referral_current_salary']=np.where(df['referral_current_salary']>ur_curr_sal,ur_curr_sal,df['referral_current_salary'])
df['referral_current_salary']=np.where(df['referral_current_salary']<lr_curr_sal,lr_curr_sal,df['referral_current_salary'])



lr_10th,ur_10th=remove_outlier(df['referral_10_th_marks'])
df['referral_10_th_marks']=np.where(df['referral_10_th_marks']>ur_10th,ur_10th,df['referral_10_th_marks'])
df['referral_10_th_marks']=np.where(df['referral_10_th_marks']<lr_10th,lr_10th,df['referral_10_th_marks'])


lr_12th,ur_12th=remove_outlier(df['referral_12th_marks'])
df['referral_12th_marks']=np.where(df['referral_12th_marks']>ur_12th,ur_12th,df['referral_12th_marks'])
df['referral_12th_marks']=np.where(df['referral_12th_marks']<lr_12th,lr_12th,df['referral_12th_marks'])



lr_grd_mark,ur_grd_mark=remove_outlier(df['referral_graduation_marks'])
df['referral_graduation_marks']=np.where(df['referral_graduation_marks']>ur_grd_mark,ur_grd_mark,df['referral_graduation_marks'])
df['referral_graduation_marks']=np.where(df['referral_graduation_marks']<lr_grd_mark,lr_grd_mark,df['referral_graduation_marks'])

lr_exp_sal,ur_exp_sal=remove_outlier(df['referral_expected_sal'])
df['referral_expected_sal']=np.where(df['referral_expected_sal']>ur_exp_sal,ur_exp_sal,df['referral_expected_sal'])
df['referral_expected_sal']=np.where(df['referral_expected_sal']<lr_exp_sal,lr_exp_sal,df['referral_expected_sal'])



lr_hr_score,ur_hr_score=remove_outlier(df['referral_HR_Interview_score'])
df['referral_HR_Interview_score']=np.where(df['referral_HR_Interview_score']>ur_hr_score,ur_hr_score,df['referral_HR_Interview_score'])
df['referral_HR_Interview_score']=np.where(df['referral_HR_Interview_score']<lr_hr_score,lr_hr_score,df['referral_HR_Interview_score'])


lr_sal_ofr,ur_sal_ofr=remove_outlier(df['Salary offered'])
df['Salary offered']=np.where(df['Salary offered']>ur_sal_ofr,ur_sal_ofr,df['Salary offered'])
df['Salary offered']=np.where(df['Salary offered']<lr_sal_ofr,lr_sal_ofr,df['Salary offered'])

# %%
sns.boxplot(x='referral_age',data=df);

# %%
sns.boxplot(x='referral_exp_in_years',data=df);

# %%
sns.boxplot(x='referral_current_salary',data=df);

# %%
sns.boxplot(x='referral_10_th_marks',data=df);

# %%
sns.boxplot(x='referral_12th_marks',data=df);

# %%
sns.boxplot(x='referral_graduation_marks',data=df);

# %%
sns.boxplot(x='referral_expected_sal',data=df);

# %%
sns.boxplot(x='referral_HR_Interview_score',data=df);

# %%
sns.boxplot(x='Salary offered',data=df);

# %% [markdown]
# ## DATA Scaling ( on numerical variables)

# %% [markdown]
# ### 1) Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_scale=StandardScaler()
std_scale
# Out:
# StandardScaler()

# %%
df_std=df.copy()
df_std.head()
# Out:
#    referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 0            1          28.0                    5.0                   Delhi
# 1            2          26.0                    3.0                    Pune
# 2            3          23.0                    2.0                  Mumbai
# 3            4          29.0                    6.0               Bangalore
# 4            5          26.0                    3.0                  Mumbai
#
#    referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 0                    106.0                  89.0                 72.0
# 1                     65.0                  63.0                 77.0
# 2                     45.0                  92.0                 85.0
# 3                    126.0                  60.0                 95.0
# 4                     65.0                  92.0                 70.0
#
#    referral_graduation_marks  referral_post_grad_marks referral_gender  \
# ...

# %%
df_std['referral_age']=std_scale.fit_transform(df_std[['referral_age']])
df_std['referral_exp_in_years']=std_scale.fit_transform(df_std[['referral_exp_in_years']])
df_std['referral_current_salary ']=std_scale.fit_transform(df_std[['referral_current_salary']])

df_std['referral_10_th_marks']=std_scale.fit_transform(df_std[['referral_10_th_marks']])
df_std['referral_12th_marks']=std_scale.fit_transform(df_std[['referral_12th_marks']])
df_std['referral_graduation_marks']=std_scale.fit_transform(df_std[['referral_graduation_marks']])

df_std['referral_post_grad_marks']=std_scale.fit_transform(df_std[['referral_post_grad_marks']])

df_std['referral_expected_sal ']=std_scale.fit_transform(df_std[['referral_expected_sal']])

df_std['referral_aptitude_verbal_score ']=std_scale.fit_transform(df_std[['referral_aptitude_verbal_score']])

df_std['referral_Management_Interview_score ']=std_scale.fit_transform(df_std[['referral_Management_Interview_score']])


df_std['referral_HR_Interview_score']=std_scale.fit_transform(df_std[['referral_HR_Interview_score']])

df_std['Salary offered ']=std_scale.fit_transform(df_std[['Salary offered']])

# %%
df_std['referral_aptitude_numerical_score']=std_scale.fit_transform(df_std[['referral_aptitude_numerical_score']])
df_std['referral_aptitude_reasoning_score']=std_scale.fit_transform(df_std[['referral_aptitude_reasoning_score']])

# %%
df_std.head()
# Out:
#    referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 0            1      0.459446               0.501235                   Delhi
# 1            2     -0.424036              -0.494450                    Pune
# 2            3     -1.749260              -0.992293                  Mumbai
# 3            4      0.901188               0.999077               Bangalore
# 4            5     -0.424036              -0.494450                  Mumbai
#
#    referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 0                    106.0              1.089143            -0.520616
# 1                     65.0             -1.346948            -0.050668
# 2                     45.0              1.370231             0.701249
# 3                    126.0             -1.628035             1.641145
# 4                     65.0              1.370231            -0.708595
#
#    referral_graduation_marks  referral_post_grad_marks referral_gender  ...  \
# ...

# %% [markdown]
# ### 2) Min Max Scaler (0 to 1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df_minmax=df.copy()
df_minmax.head()
# Out:
#    referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 0            1          28.0                    5.0                   Delhi
# 1            2          26.0                    3.0                    Pune
# 2            3          23.0                    2.0                  Mumbai
# 3            4          29.0                    6.0               Bangalore
# 4            5          26.0                    3.0                  Mumbai
#
#    referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 0                    106.0                  89.0                 72.0
# 1                     65.0                  63.0                 77.0
# 2                     45.0                  92.0                 85.0
# 3                    126.0                  60.0                 95.0
# 4                     65.0                  92.0                 70.0
#
#    referral_graduation_marks  referral_post_grad_marks referral_gender  \
# ...

# %%
minmax=MinMaxScaler()
minmax
# Out:
# MinMaxScaler()

# %%
df_minmax['referral_age']=minmax.fit_transform(df_minmax[['referral_age']])
df_minmax['referral_exp_in_years']=minmax.fit_transform(df_minmax[['referral_exp_in_years']])
df_minmax['referral_current_salary ']=minmax.fit_transform(df_minmax[['referral_current_salary']])

df_minmax['referral_10_th_marks']=minmax.fit_transform(df_minmax[['referral_10_th_marks']])
df_minmax['referral_12th_marks']=minmax.fit_transform(df_minmax[['referral_12th_marks']])
df_minmax['referral_graduation_marks']=minmax.fit_transform(df_minmax[['referral_graduation_marks']])

df_minmax['referral_post_grad_marks']=minmax.fit_transform(df_minmax[['referral_post_grad_marks']])

df_minmax['referral_expected_sal ']=minmax.fit_transform(df_minmax[['referral_expected_sal']])

df_minmax['referral_aptitude_verbal_score ']=minmax.fit_transform(df_minmax[['referral_aptitude_verbal_score']])

df_minmax['referral_Management_Interview_score ']=minmax.fit_transform(df_minmax[['referral_Management_Interview_score']])


df_minmax['referral_HR_Interview_score']=minmax.fit_transform(df_minmax[['referral_HR_Interview_score']])

df_minmax['Salary offered ']=minmax.fit_transform(df_minmax[['Salary offered']])

# %%
df_minmax.head()
# Out:
#    referral_age  referral_exp_in_years referral_preferred_city  \
# 0      0.533333               0.363636                   Delhi
# 1      0.400000               0.181818                    Pune
# 2      0.200000               0.090909                  Mumbai
# 3      0.600000               0.454545               Bangalore
# 4      0.400000               0.181818                  Mumbai
#
#    referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 0                    106.0              0.779528             0.566038
# 1                     65.0              0.370079             0.660377
# 2                     45.0              0.826772             0.811321
# 3                    126.0              0.322835             1.000000
# 4                     65.0              0.826772             0.528302
#
#    referral_graduation_marks  referral_post_grad_marks referral_gender  \
# 0                   0.730159                  0.560976            Male
# ...

# %%
df_minmax.drop('referral_id',axis=1,inplace=True)

# %%
df_minmax.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Variable Transformation (on categorical variable)

# %% [markdown]
# ## 1) One Hot EnCoding

# %%
df_ohe=df.copy()
df_ohe
# Out:
#      referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 0              1          28.0                    5.0                   Delhi
# 1              2          26.0                    3.0                    Pune
# 2              3          23.0                    2.0                  Mumbai
# 3              4          29.0                    6.0               Bangalore
# 4              5          26.0                    3.0                  Mumbai
# ..           ...           ...                    ...                     ...
# 494          495          21.0                    1.0                    Pune
# 495          496          21.0                    1.0                  Mumbai
# 496          497          29.0                    7.0                  Mumbai
# 497          498          30.0                    7.0                  Mumbai
# 498          499          30.0                    8.0               Bangalore
#
# ...

# %%
df_ohe=pd.get_dummies(df_ohe,drop_first=True)
df_ohe
# Out:
#      referral_id  referral_age  referral_exp_in_years  \
# 0              1          28.0                    5.0
# 1              2          26.0                    3.0
# 2              3          23.0                    2.0
# 3              4          29.0                    6.0
# 4              5          26.0                    3.0
# ..           ...           ...                    ...
# 494          495          21.0                    1.0
# 495          496          21.0                    1.0
# 496          497          29.0                    7.0
# 497          498          30.0                    7.0
# 498          499          30.0                    8.0
#
#      referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 0                      106.0                  89.0                 72.0
# 1                       65.0                  63.0                 77.0
# 2                       45.0                  92.0                 85.0
# ...

# %% [markdown]
# ## 2) Label EnCoding

# %%
df_le=df.copy()
df_le
# Out:
#      referral_id  referral_age  referral_exp_in_years referral_preferred_city  \
# 0              1          28.0                    5.0                   Delhi
# 1              2          26.0                    3.0                    Pune
# 2              3          23.0                    2.0                  Mumbai
# 3              4          29.0                    6.0               Bangalore
# 4              5          26.0                    3.0                  Mumbai
# ..           ...           ...                    ...                     ...
# 494          495          21.0                    1.0                    Pune
# 495          496          21.0                    1.0                  Mumbai
# 496          497          29.0                    7.0                  Mumbai
# 497          498          30.0                    7.0                  Mumbai
# 498          499          30.0                    8.0               Bangalore
#
# ...

# %%
for feature in df_le.columns:
    df_le[feature]=pd.Categorical(df_le[feature]).codes

# %%
df_le.head()
# Out:
#    referral_id  referral_age  referral_exp_in_years  referral_preferred_city  \
# 0            0             8                      8                        1
# 1            1             6                      3                        3
# 2            2             3                      2                        2
# 3            3             9                     11                        0
# 4            4             6                      3                        2
#
#    referral_current_salary  referral_10_th_marks  referral_12th_marks  \
# 0                       10                    30                   13
# 1                        5                     4                   18
# 2                        2                    33                   26
# 3                       13                     1                   36
# 4                        5                    33                   11
#
#    referral_graduation_marks  referral_post_grad_marks  referral_gender  \
# ...
